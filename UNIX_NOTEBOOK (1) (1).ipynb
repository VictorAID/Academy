# %% [markdown]
# ### 1. Find all files in the home directory that are smaller than 1MB in size.

# %%
# %%bash
# find ~ -size -1M
# Out:
# /home/jovyan/Backup/example.txt
# /home/jovyan/TextFiles/example.txt
# /home/jovyan/examples/Notebook/nbpackage/nbs/__init__.py
# /home/jovyan/examples/Notebook/nbpackage/__init__.py
# /home/jovyan/examples/IPython Kernel/nbpackage/nbs/__init__.py
# /home/jovyan/examples/IPython Kernel/nbpackage/__init__.py

# %% [markdown]
# ### 2. Find all files in the home directory that are larger than 1MB in size.

# %%
# %%bash
# find ~ -size +1M
# Out:
# /home/jovyan/examples/Interactive Widgets/Image Processing.ipynb
# /home/jovyan/.git/objects/pack/pack-dd414f5ab49992f00c580152308d4f75a6825501.pack
# /home/jovyan/exercises/images/coffee.npy
# /home/jovyan/exercises/Parallel Computing/haarcascade_frontalface_default.xml

# %% [markdown]
# ### 3. List all files with their owners and permissions.

# %%
ls -l
# Out:
# total 128
# drwxr-xr-x  2 jovyan jovyan  4096 Apr 27 07:39  Backup/
# drwxr-xr-x  1 jovyan jovyan  4096 Apr 27 07:36  binder/
# -rw-r--r--  1 jovyan jovyan   135 Apr 27 07:39  blossom_academy_.tar.gz
# drwxr-xr-x 10 jovyan jovyan  4096 Feb 23  2022  examples/
# drwxr-xr-x 10 jovyan jovyan  4096 Feb 23  2022  exercises/
# -rw-r--r--  1 jovyan jovyan   699 Feb 23  2022  fabfile.py
# drwxr-xr-x  2 jovyan jovyan  4096 Apr 27 07:39  Garden/
# -rw-r--r--  1 jovyan jovyan  2755 Feb 23  2022  Index.ipynb
# -rw-r--r--  1 jovyan jovyan 17626 Feb 23  2022  LICENSE
# -rwxr-xr-x  1 jovyan jovyan   466 Feb 23  2022  monitor.sh*
# -rw-r--r--  1 jovyan jovyan  2756 Feb 23  2022  pycon-2015-abstract.md
# -rw-r--r--  1 jovyan jovyan  6824 Feb 23  2022  pycon-submission.md
# -rw-r--r--  1 jovyan jovyan  1802 Feb 23  2022  README.md
# drwxr-xr-x  2 jovyan jovyan  4096 Apr 27 07:38  spring/
# drwxr-xr-x  2 jovyan jovyan  4096 Apr 27 07:39  TextFiles/
# ...

# %% [markdown]
# ### 4. Write Blossom Academy is the best in the file named app.txt and display the content

# %%
# %%bash
# touch app.txt

# %%
# %%bash
# echo "Blossom Academy is the best in the file" > app.txt

# %%
# %%bash
# cat app.txt
# Out:
# Blossom Academy is the best in the file

# %% [markdown]
# ### 5. Append Thank you Blossom Academy for this Opportunity to the file named app.txt and display the content

# %%
# %%bash
# echo "Thank You Blossom Academy for this Opportunity" >> app.txt

# %%
cat app.txt
# Out:
# Blossom Academy is the best in the file
# Thank You Blossom Academy for this Opportunity

# %%
ls
# Out:
#  app.txt                   fabfile.py               pycon-submission.md
#  Backup/                   Garden/                  README.md
#  binder/                   Index.ipynb              spring/
#  blossom_academy_.tar.gz   LICENSE                  TextFiles/
#  examples/                 monitor.sh*              tools/
#  exercises/                pycon-2015-abstract.md  'UNIX_NOTEBOOK (1).ipynb'

# %% [markdown]
# ### 6. List all files and directories in TextFiles/ and save the list to a file named directory.txt

# %%
# %%bash
# touch directory_list
#
# ls TextFiles/ > directory_list.txt

# %%
ls
# Out:
#  app.txt                   exercises/               pycon-submission.md
#  Backup/                   fabfile.py               README.md
#  binder/                   Garden/                  spring/
#  blossom_academy_.tar.gz   Index.ipynb              TextFiles/
#  directory_list            LICENSE                  tools/
#  directory_list.txt        monitor.sh*             'UNIX_NOTEBOOK (1).ipynb'
#  examples/                 pycon-2015-abstract.md

# %% [markdown]
# ### 7. Remove the file directory_list.txt

# %%
rm directory_list.txt

# %% [markdown]
# ### 8. Remove the Garden directory and all its contents

# %%
rm -r Garden

# %%
ls
# Out:
#  app.txt                   exercises/               pycon-submission.md
#  Backup/                   fabfile.py               README.md
#  binder/                   Index.ipynb              spring/
#  blossom_academy_.tar.gz   LICENSE                  TextFiles/
#  directory_list            monitor.sh*              tools/
#  examples/                 pycon-2015-abstract.md  'UNIX_NOTEBOOK (1).ipynb'

# %% [markdown]
# ### 9. Create a new directory named Autumn and Spring

# %%
# %%bash
#
# mkdir Autumn Blossom

# %% [markdown]
# ### 10. Redirect the contents of directory_list.txt to a new file named sorted_list.txt

# %%
# %%bash
#
# touch directory_list
#
# ls TextFiles/ > directory_list.txt

# %%
# %%bash
# touch sorted_list.txt
# cat directory_list.txt | sort > sorted_list.txt

# %%
# %%bash
# cat sorted_list.txt
# Out:
# example.txt

# %% [markdown]
# ### 11. create a new file named sunflower.txt and write the following contents:
#
# ##### Blossom
# ##### Academy
# ##### Nigeria
# ##### Ghana
# ##### Country
# ##### Digital
# ##### Africa

# %%
# %%bash
#
# touch sunflower.txt

# %%
# %%bash
# echo -e "Blossom\n Academy\n Nigeria\n Ghana\n Country\n Digital\n Africa" > sunflower.txt

# %% [markdown]
# ### 12. Display the last 5 lines of sunflower.txt

# %%
# %%bash
#
# tail -n 5 sunflower.txt
# Out:
#  Nigeria
#  Ghana
#  Country
#  Digital
#  Africa

# %% [markdown]
# ### 13. Display the first 5 lines of sunflower.txt

# %%
# %%bash
#
# head -n 5 sunflower.txt
# Out:
# Blossom
#  Academy
#  Nigeria
#  Ghana
#  Country

# %%
ls
# Out:
#  app.txt                   examples/                README.md
#  Autumn/                   exercises/               sorted_list.txt
#  Backup/                   fabfile.py               spring/
#  binder/                   Index.ipynb              sunflower.txt
#  Blossom/                  LICENSE                  TextFiles/
#  blossom_academy_.tar.gz   monitor.sh*              tools/
#  directory_list            pycon-2015-abstract.md  'UNIX_NOTEBOOK (1).ipynb'
#  directory_list.txt        pycon-submission.md

# %% [markdown]
# ### 14. Extract the contents of blossom_academy.tar.gz in the the folder directory named tmp

# %%
# %%bash
# mkdir hmp
#
#
# tar -xvf blossom_academy_.tar.gz -C hmp
# Out:
# TextFiles/example.txt

# %%
# %%bash
#
# cd hmp
# ls
# Out:
# TextFiles

# %%
# %%bash
#
# rm -r spring

# %% [markdown]
# ### 15. Create a file named banana.txt and echo " Manchester United is the best club in England"

# %%
# %%bash
#
# echo "Manchester United is the best club in England" > banana.txt

# %% [markdown]
# ### 16. Create a file named orange.txt and echo "I love Manchester United"

# %%
# %%bash
#
# echo "I love Manchester united" > orange.txt

# %% [markdown]
# ### 17. Find the word "United" in banana.txt and orange.txt

# %%
# %%bash
#
# grep "United" banana.txt
# Out:
# Manchester United is the best club in England

# %%
# %%bash
# grep -i "United" orange.txt
# Out:
# I love Manchester united
